# %%
import pandas as pd
import xml.etree.ElementTree as xet

# %%
from glob import glob

# %%
path = glob('./images_labeled_xml/*.xml')
path
# Out:
# ['./images_labeled_xml\\N1.xml',
#  './images_labeled_xml\\N100.xml',
#  './images_labeled_xml\\N101.xml',
#  './images_labeled_xml\\N102.xml',
#  './images_labeled_xml\\N103.xml',
#  './images_labeled_xml\\N104.xml',
#  './images_labeled_xml\\N105.xml',
#  './images_labeled_xml\\N106.xml',
#  './images_labeled_xml\\N107.xml',
#  './images_labeled_xml\\N108.xml',
#  './images_labeled_xml\\N109.xml',
#  './images_labeled_xml\\N11.xml',
#  './images_labeled_xml\\N110.xml',
#  './images_labeled_xml\\N111.xml',
#  './images_labeled_xml\\N112.xml',
#  './images_labeled_xml\\N113.xml',
#  './images_labeled_xml\\N114.xml',
#  './images_labeled_xml\\N116.xml',
#  './images_labeled_xml\\N117.xml',
#  './images_labeled_xml\\N118.xml',
#  './images_labeled_xml\\N119.xml',
#  './images_labeled_xml\\N12.xml',
#  './images_labeled_xml\\N120.xml',
#  './images_labeled_xml\\N121.xml',
#  './images_labeled_xml\\N122.xml',
#  './images_labeled_xml\\N123.xml',
#  './images_labeled_xml\\N124.xml',
#  './images_labeled_xml\\N126.xml',
#  './images_labeled_xml\\N127.xml',
#  './images_labeled_xml\\N128.xml',
#  './images_labeled_xml\\N129.xml',
#  './images_labeled_xml\\N130.xml',
#  './images_labeled_xml\\N131.xml',
#  './images_labeled_xml\\N132.xml',
#  './images_labeled_xml\\N133.xml',
#  './images_labeled_xml\\N134.xml',
#  './images_labeled_xml\\N135.xml',
#  './images_labeled_xml\\N136.xml',
#  './images_labeled_xml\\N137.xml',
#  './images_labeled_xml\\N138.xml',
#  './images_labeled_xml\\N139.xml',
#  './images_labeled_xml\\N14.xml',
#  './images_labeled_xml\\N140.xml',
#  './images_labeled_xml\\N141.xml',
#  './images_labeled_xml\\N142.xml',
#  './images_labeled_xml\\N143.xml',
#  './images_labeled_xml\\N144.xml',
#  './images_labeled_xml\\N145.xml',
#  './images_labeled_xml\\N147.xml',
#  './images_labeled_xml\\N148.xml',
#  './images_labeled_xml\\N149.xml',
#  './images_labeled_xml\\N15.xml',
#  './images_labeled_xml\\N150.xml',
#  './images_labeled_xml\\N151.xml',
#  './images_labeled_xml\\N152.xml',
#  './images_labeled_xml\\N153.xml',
#  './images_labeled_xml\\N154.xml',
#  './images_labeled_xml\\N155.xml',
#  './images_labeled_xml\\N156.xml',
#  './images_labeled_xml\\N158.xml',
#  './images_labeled_xml\\N16.xml',
#  './images_labeled_xml\\N160.xml',
#  './images_labeled_xml\\N162.xml',
#  './images_labeled_xml\\N163.xml',
#  './images_labeled_xml\\N164.xml',
#  './images_labeled_xml\\N165.xml',
#  './images_labeled_xml\\N166.xml',
#  './images_labeled_xml\\N167.xml',
#  './images_labeled_xml\\N168.xml',
#  './images_labeled_xml\\N169.xml',
#  './images_labeled_xml\\N17.xml',
#  './images_labeled_xml\\N170.xml',
#  './images_labeled_xml\\N171.xml',
#  './images_labeled_xml\\N172.xml',
#  './images_labeled_xml\\N173.xml',
#  './images_labeled_xml\\N174.xml',
#  './images_labeled_xml\\N175.xml',
#  './images_labeled_xml\\N176.xml',
#  './images_labeled_xml\\N177.xml',
#  './images_labeled_xml\\N178.xml',
#  './images_labeled_xml\\N179.xml',
#  './images_labeled_xml\\N18.xml',
#  './images_labeled_xml\\N181.xml',
#  './images_labeled_xml\\N183.xml',
#  './images_labeled_xml\\N184.xml',
#  './images_labeled_xml\\N185.xml',
#  './images_labeled_xml\\N186.xml',
#  './images_labeled_xml\\N187.xml',
#  './images_labeled_xml\\N188.xml',
#  './images_labeled_xml\\N189.xml',
#  './images_labeled_xml\\N19.xml',
#  './images_labeled_xml\\N190.xml',
#  './images_labeled_xml\\N191.xml',
#  './images_labeled_xml\\N192.xml',
#  './images_labeled_xml\\N193.xml',
#  './images_labeled_xml\\N195.xml',
#  './images_labeled_xml\\N196.xml',
#  './images_labeled_xml\\N197.xml',
#  './images_labeled_xml\\N198.xml',
#  './images_labeled_xml\\N199.xml',
#  './images_labeled_xml\\N2.xml',
#  './images_labeled_xml\\N20.xml',
#  './images_labeled_xml\\N200.xml',
#  './images_labeled_xml\\N201.xml',
#  './images_labeled_xml\\N202.xml',
#  './images_labeled_xml\\N203.xml',
#  './images_labeled_xml\\N204.xml',
#  './images_labeled_xml\\N205.xml',
#  './images_labeled_xml\\N206.xml',
#  './images_labeled_xml\\N207.xml',
#  './images_labeled_xml\\N208.xml',
#  './images_labeled_xml\\N209.xml',
#  './images_labeled_xml\\N21.xml',
#  './images_labeled_xml\\N210.xml',
#  './images_labeled_xml\\N211.xml',
#  './images_labeled_xml\\N212.xml',
#  './images_labeled_xml\\N213.xml',
#  './images_labeled_xml\\N214.xml',
#  './images_labeled_xml\\N215.xml',
#  './images_labeled_xml\\N216.xml',
#  './images_labeled_xml\\N217.xml',
#  './images_labeled_xml\\N218.xml',
#  './images_labeled_xml\\N219.xml',
#  './images_labeled_xml\\N22.xml',
#  './images_labeled_xml\\N220.xml',
#  './images_labeled_xml\\N221.xml',
#  './images_labeled_xml\\N222.xml',
#  './images_labeled_xml\\N223.xml',
#  './images_labeled_xml\\N224.xml',
#  './images_labeled_xml\\N225.xml',
#  './images_labeled_xml\\N226.xml',
#  './images_labeled_xml\\N227.xml',
#  './images_labeled_xml\\N229.xml',
#  './images_labeled_xml\\N23.xml',
#  './images_labeled_xml\\N230.xml',
#  './images_labeled_xml\\N231.xml',
#  './images_labeled_xml\\N232.xml',
#  './images_labeled_xml\\N233.xml',
#  './images_labeled_xml\\N234.xml',
#  './images_labeled_xml\\N235.xml',
#  './images_labeled_xml\\N236.xml',
#  './images_labeled_xml\\N237.xml',
#  './images_labeled_xml\\N238.xml',
#  './images_labeled_xml\\N239.xml',
#  './images_labeled_xml\\N24.xml',
#  './images_labeled_xml\\N240.xml',
#  './images_labeled_xml\\N241.xml',
#  './images_labeled_xml\\N242.xml',
#  './images_labeled_xml\\N244.xml',
#  './images_labeled_xml\\N245.xml',
#  './images_labeled_xml\\N246.xml',
#  './images_labeled_xml\\N247.xml',
#  './images_labeled_xml\\N248.xml',
#  './images_labeled_xml\\N25.xml',
#  './images_labeled_xml\\N27.xml',
#  './images_labeled_xml\\N28.xml',
#  './images_labeled_xml\\N3.xml',
#  './images_labeled_xml\\N30.xml',
#  './images_labeled_xml\\N31.xml',
#  './images_labeled_xml\\N32.xml',
#  './images_labeled_xml\\N33.xml',
#  './images_labeled_xml\\N34.xml',
#  './images_labeled_xml\\N35.xml',
#  './images_labeled_xml\\N36.xml',
#  './images_labeled_xml\\N37.xml',
#  './images_labeled_xml\\N38.xml',
#  './images_labeled_xml\\N4.xml',
#  './images_labeled_xml\\N40.xml',
#  './images_labeled_xml\\N42.xml',
#  './images_labeled_xml\\N43.xml',
#  './images_labeled_xml\\N44.xml',
#  './images_labeled_xml\\N45.xml',
#  './images_labeled_xml\\N46.xml',
#  './images_labeled_xml\\N47.xml',
#  './images_labeled_xml\\N48.xml',
#  './images_labeled_xml\\N49.xml',
#  './images_labeled_xml\\N5.xml',
#  './images_labeled_xml\\N50.xml',
#  './images_labeled_xml\\N51.xml',
#  './images_labeled_xml\\N52.xml',
#  './images_labeled_xml\\N53.xml',
#  './images_labeled_xml\\N54.xml',
#  './images_labeled_xml\\N56.xml',
#  './images_labeled_xml\\N57.xml',
#  './images_labeled_xml\\N58.xml',
#  './images_labeled_xml\\N59.xml',
#  './images_labeled_xml\\N6.xml',
#  './images_labeled_xml\\N61.xml',
#  './images_labeled_xml\\N62.xml',
#  './images_labeled_xml\\N63.xml',
#  './images_labeled_xml\\N64.xml',
#  './images_labeled_xml\\N65.xml',
#  './images_labeled_xml\\N66.xml',
#  './images_labeled_xml\\N67.xml',
#  './images_labeled_xml\\N68.xml',
#  './images_labeled_xml\\N69.xml',
#  './images_labeled_xml\\N7.xml',
#  './images_labeled_xml\\N70.xml',
#  './images_labeled_xml\\N72.xml',
#  './images_labeled_xml\\N73.xml',
#  './images_labeled_xml\\N74.xml',
#  './images_labeled_xml\\N75.xml',
#  './images_labeled_xml\\N77.xml',
#  './images_labeled_xml\\N78.xml',
#  './images_labeled_xml\\N79.xml',
#  './images_labeled_xml\\N8.xml',
#  './images_labeled_xml\\N80.xml',
#  './images_labeled_xml\\N81.xml',
#  './images_labeled_xml\\N82.xml',
#  './images_labeled_xml\\N84.xml',
#  './images_labeled_xml\\N85.xml',
#  './images_labeled_xml\\N86.xml',
#  './images_labeled_xml\\N88.xml',
#  './images_labeled_xml\\N89.xml',
#  './images_labeled_xml\\N9.xml',
#  './images_labeled_xml\\N90.xml',
#  './images_labeled_xml\\N91.xml',
#  './images_labeled_xml\\N92.xml',
#  './images_labeled_xml\\N93.xml',
#  './images_labeled_xml\\N94.xml',
#  './images_labeled_xml\\N95.xml',
#  './images_labeled_xml\\N96.xml',
#  './images_labeled_xml\\N97.xml',
#  './images_labeled_xml\\N98.xml',
#  './images_labeled_xml\\N99.xml']

# %%
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path:

    #filename = path[0]
    info = xet.parse(filename)
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin = int(labels_info.find('xmin').text)
    xmax = int(labels_info.find('xmax').text)
    ymin = int(labels_info.find('ymin').text)
    ymax = int(labels_info.find('ymax').text)
    #print(xmin,xmax,ymin,ymax)
    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %%
df = pd.DataFrame(labels_dict)
df
# Out:
#                           filepath  xmin  xmax  ymin  ymax
# 0      ./images_labeled_xml\N1.xml  1093  1396   645   727
# 1    ./images_labeled_xml\N100.xml   134   301   312   350
# 2    ./images_labeled_xml\N101.xml    31   139   128   161
# 3    ./images_labeled_xml\N102.xml   164   316   216   243
# 4    ./images_labeled_xml\N103.xml   813  1067   665   724
# ..                             ...   ...   ...   ...   ...
# 220   ./images_labeled_xml\N95.xml    23   408   173   391
# 221   ./images_labeled_xml\N96.xml   137   352   141   186
# 222   ./images_labeled_xml\N97.xml   175   290   228   255
# 223   ./images_labeled_xml\N98.xml   563   675   207   238
# 224   ./images_labeled_xml\N99.xml   158   389   129   193
#
# [225 rows x 5 columns]

# %%
df.to_csv('labels.csv',index=False)
